# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          1152        input_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          16512       dense_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           8256        dense_7[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_7[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_8[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 884us/sample - loss: 254.7166 - y1_output_loss: 122.3062 - y2_output_loss: 130.2840 - y1_output_root_mean_squared_error: 11.1087 - y2_output_root_mean_squared_error: 11.4592 - val_loss: 69.2431 - val_y1_output_loss: 20.5537 - val_y2_output_loss: 47.6077 - val_y1_output_root_mean_squared_error: 4.6149 - val_y2_output_root_mean_squared_error: 6.9243
# Epoch 2/500
# 614/614 [==============================] - 0s 164us/sample - loss: 33.4270 - y1_output_loss: 12.5886 - y2_output_loss: 20.5800 - y1_output_root_mean_squared_error: 3.5645 - y2_output_root_mean_squared_error: 4.5521 - val_loss: 30.2559 - val_y1_output_loss: 12.7980 - val_y2_output_loss: 16.9941 - val_y1_output_root_mean_squared_error: 3.6256 - val_y2_output_root_mean_squared_error: 4.1365
# Epoch 3/500
# 614/614 [==============================] - 0s 141us/sample - loss: 27.1413 - y1_output_loss: 9.7718 - y2_output_loss: 17.1845 - y1_output_root_mean_squared_error: 3.1355 - y2_output_root_mean_squared_error: 4.1605 - val_loss: 28.2000 - val_y1_output_loss: 12.2224 - val_y2_output_loss: 15.5484 - val_y1_output_root_mean_squared_error: 3.5349 - val_y2_output_root_mean_squared_error: 3.9629
# Epoch 4/500
# 614/614 [==============================] - 0s 141us/sample - loss: 24.6405 - y1_output_loss: 9.3722 - y2_output_loss: 15.0561 - y1_output_root_mean_squared_error: 3.0742 - y2_output_root_mean_squared_error: 3.8974 - val_loss: 33.5659 - val_y1_output_loss: 12.0270 - val_y2_output_loss: 21.5430 - val_y1_output_root_mean_squared_error: 3.4843 - val_y2_output_root_mean_squared_error: 4.6288
# Epoch 5/500
# 614/614 [==============================] - 0s 144us/sample - loss: 22.9132 - y1_output_loss: 8.7194 - y2_output_loss: 14.2074 - y1_output_root_mean_squared_error: 2.9420 - y2_output_root_mean_squared_error: 3.7760 - val_loss: 25.3697 - val_y1_output_loss: 11.7180 - val_y2_output_loss: 14.1518 - val_y1_output_root_mean_squared_error: 3.3728 - val_y2_output_root_mean_squared_error: 3.7408
# Epoch 6/500
# 614/614 [==============================] - 0s 140us/sample - loss: 21.6009 - y1_output_loss: 8.4682 - y2_output_loss: 13.0369 - y1_output_root_mean_squared_error: 2.9213 - y2_output_root_mean_squared_error: 3.6148 - val_loss: 27.4766 - val_y1_output_loss: 10.7902 - val_y2_output_loss: 16.5736 - val_y1_output_root_mean_squared_error: 3.2814 - val_y2_output_root_mean_squared_error: 4.0877
# Epoch 7/500
# 614/614 [==============================] - 0s 142us/sample - loss: 22.5535 - y1_output_loss: 8.7813 - y2_output_loss: 13.7241 - y1_output_root_mean_squared_error: 2.9621 - y2_output_root_mean_squared_error: 3.7121 - val_loss: 38.5645 - val_y1_output_loss: 13.1765 - val_y2_output_loss: 24.9617 - val_y1_output_root_mean_squared_error: 3.6722 - val_y2_output_root_mean_squared_error: 5.0079
# Epoch 8/500
# 614/614 [==============================] - 0s 153us/sample - loss: 25.2711 - y1_output_loss: 8.9109 - y2_output_loss: 16.1751 - y1_output_root_mean_squared_error: 2.9939 - y2_output_root_mean_squared_error: 4.0383 - val_loss: 22.4754 - val_y1_output_loss: 10.3968 - val_y2_output_loss: 12.6017 - val_y1_output_root_mean_squared_error: 3.1826 - val_y2_output_root_mean_squared_error: 3.5138
# Epoch 9/500
# 614/614 [==============================] - 0s 151us/sample - loss: 24.0450 - y1_output_loss: 8.7248 - y2_output_loss: 15.0998 - y1_output_root_mean_squared_error: 2.9661 - y2_output_root_mean_squared_error: 3.9048 - val_loss: 23.5709 - val_y1_output_loss: 11.1922 - val_y2_output_loss: 12.1186 - val_y1_output_root_mean_squared_error: 3.3478 - val_y2_output_root_mean_squared_error: 3.5162
# Epoch 10/500
# 614/614 [==============================] - 0s 139us/sample - loss: 21.6289 - y1_output_loss: 8.2685 - y2_output_loss: 13.7145 - y1_output_root_mean_squared_error: 2.8563 - y2_output_root_mean_squared_error: 3.6702 - val_loss: 29.5716 - val_y1_output_loss: 10.5134 - val_y2_output_loss: 19.3121 - val_y1_output_root_mean_squared_error: 3.2138 - val_y2_output_root_mean_squared_error: 4.3867
# Epoch 11/500
# 614/614 [==============================] - 0s 144us/sample - loss: 19.3677 - y1_output_loss: 7.7370 - y2_output_loss: 11.9234 - y1_output_root_mean_squared_error: 2.7687 - y2_output_root_mean_squared_error: 3.4208 - val_loss: 137.8544 - val_y1_output_loss: 25.0617 - val_y2_output_loss: 112.8846 - val_y1_output_root_mean_squared_error: 4.9828 - val_y2_output_root_mean_squared_error: 10.6314
# Epoch 12/500
# 614/614 [==============================] - 0s 145us/sample - loss: 20.0750 - y1_output_loss: 7.6846 - y2_output_loss: 12.4408 - y1_output_root_mean_squared_error: 2.7557 - y2_output_root_mean_squared_error: 3.5329 - val_loss: 20.7516 - val_y1_output_loss: 9.5927 - val_y2_output_loss: 11.1687 - val_y1_output_root_mean_squared_error: 3.0831 - val_y2_output_root_mean_squared_error: 3.3535
# Epoch 13/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.7135 - y1_output_loss: 7.3585 - y2_output_loss: 11.2388 - y1_output_root_mean_squared_error: 2.7220 - y2_output_root_mean_squared_error: 3.3622 - val_loss: 20.3600 - val_y1_output_loss: 9.1212 - val_y2_output_loss: 11.2125 - val_y1_output_root_mean_squared_error: 3.0158 - val_y2_output_root_mean_squared_error: 3.3564
# Epoch 14/500
# 614/614 [==============================] - 0s 141us/sample - loss: 21.4695 - y1_output_loss: 7.7993 - y2_output_loss: 13.5042 - y1_output_root_mean_squared_error: 2.8034 - y2_output_root_mean_squared_error: 3.6893 - val_loss: 20.3221 - val_y1_output_loss: 9.4461 - val_y2_output_loss: 10.8180 - val_y1_output_root_mean_squared_error: 3.0594 - val_y2_output_root_mean_squared_error: 3.3109
# Epoch 15/500
# 614/614 [==============================] - 0s 143us/sample - loss: 19.4542 - y1_output_loss: 7.2425 - y2_output_loss: 12.2556 - y1_output_root_mean_squared_error: 2.6939 - y2_output_root_mean_squared_error: 3.4924 - val_loss: 25.5203 - val_y1_output_loss: 11.5002 - val_y2_output_loss: 14.3206 - val_y1_output_root_mean_squared_error: 3.3422 - val_y2_output_root_mean_squared_error: 3.7881
# Epoch 16/500
# 614/614 [==============================] - 0s 141us/sample - loss: 18.7954 - y1_output_loss: 7.4499 - y2_output_loss: 11.4431 - y1_output_root_mean_squared_error: 2.7050 - y2_output_root_mean_squared_error: 3.3880 - val_loss: 19.9535 - val_y1_output_loss: 8.7384 - val_y2_output_loss: 11.4013 - val_y1_output_root_mean_squared_error: 2.9285 - val_y2_output_root_mean_squared_error: 3.3730
# Epoch 17/500
# 614/614 [==============================] - 0s 143us/sample - loss: 21.1229 - y1_output_loss: 7.4944 - y2_output_loss: 13.4616 - y1_output_root_mean_squared_error: 2.7497 - y2_output_root_mean_squared_error: 3.6826 - val_loss: 19.5502 - val_y1_output_loss: 9.1393 - val_y2_output_loss: 10.5557 - val_y1_output_root_mean_squared_error: 2.9885 - val_y2_output_root_mean_squared_error: 3.2587
# Epoch 18/500
# 614/614 [==============================] - 0s 144us/sample - loss: 16.9690 - y1_output_loss: 6.4196 - y2_output_loss: 10.7684 - y1_output_root_mean_squared_error: 2.5219 - y2_output_root_mean_squared_error: 3.2571 - val_loss: 84.1489 - val_y1_output_loss: 19.8559 - val_y2_output_loss: 66.0271 - val_y1_output_root_mean_squared_error: 4.3626 - val_y2_output_root_mean_squared_error: 8.0695
# Epoch 19/500
# 614/614 [==============================] - 0s 140us/sample - loss: 18.1344 - y1_output_loss: 6.9351 - y2_output_loss: 11.3926 - y1_output_root_mean_squared_error: 2.6283 - y2_output_root_mean_squared_error: 3.3506 - val_loss: 49.7095 - val_y1_output_loss: 12.6832 - val_y2_output_loss: 36.8108 - val_y1_output_root_mean_squared_error: 3.5983 - val_y2_output_root_mean_squared_error: 6.0632
# Epoch 20/500
# 614/614 [==============================] - 0s 143us/sample - loss: 18.0931 - y1_output_loss: 6.5208 - y2_output_loss: 11.4369 - y1_output_root_mean_squared_error: 2.5605 - y2_output_root_mean_squared_error: 3.3966 - val_loss: 17.9964 - val_y1_output_loss: 8.8555 - val_y2_output_loss: 9.2009 - val_y1_output_root_mean_squared_error: 2.9408 - val_y2_output_root_mean_squared_error: 3.0575
# Epoch 21/500
# 614/614 [==============================] - 0s 137us/sample - loss: 15.1833 - y1_output_loss: 6.1369 - y2_output_loss: 9.0015 - y1_output_root_mean_squared_error: 2.4866 - y2_output_root_mean_squared_error: 3.0000 - val_loss: 21.5816 - val_y1_output_loss: 7.8350 - val_y2_output_loss: 13.7980 - val_y1_output_root_mean_squared_error: 2.7737 - val_y2_output_root_mean_squared_error: 3.7267
# Epoch 22/500
# 614/614 [==============================] - 0s 142us/sample - loss: 15.2189 - y1_output_loss: 5.7961 - y2_output_loss: 9.3750 - y1_output_root_mean_squared_error: 2.4147 - y2_output_root_mean_squared_error: 3.0640 - val_loss: 16.0005 - val_y1_output_loss: 7.0921 - val_y2_output_loss: 8.8713 - val_y1_output_root_mean_squared_error: 2.6501 - val_y2_output_root_mean_squared_error: 2.9963
# Epoch 23/500
# 614/614 [==============================] - 0s 146us/sample - loss: 13.7953 - y1_output_loss: 5.5422 - y2_output_loss: 8.1609 - y1_output_root_mean_squared_error: 2.3633 - y2_output_root_mean_squared_error: 2.8653 - val_loss: 19.4835 - val_y1_output_loss: 7.5922 - val_y2_output_loss: 12.4908 - val_y1_output_root_mean_squared_error: 2.6819 - val_y2_output_root_mean_squared_error: 3.5059
# Epoch 24/500
# 614/614 [==============================] - 0s 137us/sample - loss: 13.8847 - y1_output_loss: 5.2978 - y2_output_loss: 8.4673 - y1_output_root_mean_squared_error: 2.3105 - y2_output_root_mean_squared_error: 2.9234 - val_loss: 15.2527 - val_y1_output_loss: 6.6483 - val_y2_output_loss: 8.6432 - val_y1_output_root_mean_squared_error: 2.5576 - val_y2_output_root_mean_squared_error: 2.9515
# Epoch 25/500
# 614/614 [==============================] - 0s 141us/sample - loss: 13.7250 - y1_output_loss: 5.1880 - y2_output_loss: 8.6004 - y1_output_root_mean_squared_error: 2.2845 - y2_output_root_mean_squared_error: 2.9165 - val_loss: 23.6368 - val_y1_output_loss: 6.6743 - val_y2_output_loss: 17.1150 - val_y1_output_root_mean_squared_error: 2.5621 - val_y2_output_root_mean_squared_error: 4.1319
# Epoch 26/500
# 614/614 [==============================] - 0s 143us/sample - loss: 14.0202 - y1_output_loss: 4.9650 - y2_output_loss: 9.0711 - y1_output_root_mean_squared_error: 2.2316 - y2_output_root_mean_squared_error: 3.0067 - val_loss: 27.7881 - val_y1_output_loss: 6.9599 - val_y2_output_loss: 21.2212 - val_y1_output_root_mean_squared_error: 2.6063 - val_y2_output_root_mean_squared_error: 4.5821
# Epoch 27/500
# 614/614 [==============================] - 0s 141us/sample - loss: 14.0541 - y1_output_loss: 5.1011 - y2_output_loss: 9.0271 - y1_output_root_mean_squared_error: 2.2676 - y2_output_root_mean_squared_error: 2.9853 - val_loss: 22.0750 - val_y1_output_loss: 8.2897 - val_y2_output_loss: 14.0082 - val_y1_output_root_mean_squared_error: 2.8367 - val_y2_output_root_mean_squared_error: 3.7454
# Epoch 28/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.3741 - y1_output_loss: 5.4600 - y2_output_loss: 9.9534 - y1_output_root_mean_squared_error: 2.3217 - y2_output_root_mean_squared_error: 3.1597 - val_loss: 17.4899 - val_y1_output_loss: 6.1312 - val_y2_output_loss: 11.2978 - val_y1_output_root_mean_squared_error: 2.4806 - val_y2_output_root_mean_squared_error: 3.3670
# Epoch 29/500
# 614/614 [==============================] - 0s 135us/sample - loss: 13.0644 - y1_output_loss: 4.7101 - y2_output_loss: 8.2661 - y1_output_root_mean_squared_error: 2.1734 - y2_output_root_mean_squared_error: 2.8881 - val_loss: 13.4200 - val_y1_output_loss: 5.7340 - val_y2_output_loss: 7.8175 - val_y1_output_root_mean_squared_error: 2.3692 - val_y2_output_root_mean_squared_error: 2.7941
# Epoch 30/500
# 614/614 [==============================] - 0s 136us/sample - loss: 11.1335 - y1_output_loss: 4.2707 - y2_output_loss: 6.8262 - y1_output_root_mean_squared_error: 2.0687 - y2_output_root_mean_squared_error: 2.6180 - val_loss: 15.5067 - val_y1_output_loss: 6.4572 - val_y2_output_loss: 9.2414 - val_y1_output_root_mean_squared_error: 2.5198 - val_y2_output_root_mean_squared_error: 3.0261
# Epoch 31/500
# 614/614 [==============================] - 0s 142us/sample - loss: 11.1221 - y1_output_loss: 4.0502 - y2_output_loss: 7.1183 - y1_output_root_mean_squared_error: 2.0032 - y2_output_root_mean_squared_error: 2.6663 - val_loss: 21.7749 - val_y1_output_loss: 6.4765 - val_y2_output_loss: 15.6250 - val_y1_output_root_mean_squared_error: 2.5385 - val_y2_output_root_mean_squared_error: 3.9155
# Epoch 32/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.5127 - y1_output_loss: 3.9550 - y2_output_loss: 6.6801 - y1_output_root_mean_squared_error: 1.9856 - y2_output_root_mean_squared_error: 2.5632 - val_loss: 28.5578 - val_y1_output_loss: 7.7354 - val_y2_output_loss: 20.8571 - val_y1_output_root_mean_squared_error: 2.7827 - val_y2_output_root_mean_squared_error: 4.5623
# Epoch 33/500
# 614/614 [==============================] - 0s 142us/sample - loss: 10.8479 - y1_output_loss: 3.9337 - y2_output_loss: 6.8985 - y1_output_root_mean_squared_error: 1.9876 - y2_output_root_mean_squared_error: 2.6263 - val_loss: 13.9588 - val_y1_output_loss: 4.3243 - val_y2_output_loss: 9.8228 - val_y1_output_root_mean_squared_error: 2.0563 - val_y2_output_root_mean_squared_error: 3.1194
# Epoch 34/500
# 614/614 [==============================] - 0s 147us/sample - loss: 11.8071 - y1_output_loss: 4.0274 - y2_output_loss: 7.7117 - y1_output_root_mean_squared_error: 2.0157 - y2_output_root_mean_squared_error: 2.7828 - val_loss: 15.0341 - val_y1_output_loss: 5.0668 - val_y2_output_loss: 10.1498 - val_y1_output_root_mean_squared_error: 2.2059 - val_y2_output_root_mean_squared_error: 3.1888
# Epoch 35/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.6749 - y1_output_loss: 3.6527 - y2_output_loss: 7.1445 - y1_output_root_mean_squared_error: 1.9047 - y2_output_root_mean_squared_error: 2.6546 - val_loss: 30.1451 - val_y1_output_loss: 10.4712 - val_y2_output_loss: 19.9501 - val_y1_output_root_mean_squared_error: 3.1821 - val_y2_output_root_mean_squared_error: 4.4743
# Epoch 36/500
# 614/614 [==============================] - 0s 137us/sample - loss: 12.5685 - y1_output_loss: 4.0020 - y2_output_loss: 8.4821 - y1_output_root_mean_squared_error: 2.0080 - y2_output_root_mean_squared_error: 2.9217 - val_loss: 11.6907 - val_y1_output_loss: 4.8358 - val_y2_output_loss: 6.7326 - val_y1_output_root_mean_squared_error: 2.1891 - val_y2_output_root_mean_squared_error: 2.6265
# Epoch 37/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.2604 - y1_output_loss: 3.1915 - y2_output_loss: 5.9912 - y1_output_root_mean_squared_error: 1.7938 - y2_output_root_mean_squared_error: 2.4582 - val_loss: 9.0842 - val_y1_output_loss: 3.6202 - val_y2_output_loss: 5.5329 - val_y1_output_root_mean_squared_error: 1.8768 - val_y2_output_root_mean_squared_error: 2.3584
# Epoch 38/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.6756 - y1_output_loss: 3.1105 - y2_output_loss: 5.5857 - y1_output_root_mean_squared_error: 1.7656 - y2_output_root_mean_squared_error: 2.3576 - val_loss: 13.1797 - val_y1_output_loss: 4.9139 - val_y2_output_loss: 8.6046 - val_y1_output_root_mean_squared_error: 2.1867 - val_y2_output_root_mean_squared_error: 2.8980
# Epoch 39/500
# 614/614 [==============================] - 0s 142us/sample - loss: 8.3142 - y1_output_loss: 2.9825 - y2_output_loss: 5.4441 - y1_output_root_mean_squared_error: 1.7210 - y2_output_root_mean_squared_error: 2.3135 - val_loss: 9.6420 - val_y1_output_loss: 3.5183 - val_y2_output_loss: 6.2583 - val_y1_output_root_mean_squared_error: 1.8593 - val_y2_output_root_mean_squared_error: 2.4870
# Epoch 40/500
# 614/614 [==============================] - 0s 139us/sample - loss: 9.2627 - y1_output_loss: 3.1263 - y2_output_loss: 6.1622 - y1_output_root_mean_squared_error: 1.7621 - y2_output_root_mean_squared_error: 2.4815 - val_loss: 9.7007 - val_y1_output_loss: 3.6368 - val_y2_output_loss: 6.3809 - val_y1_output_root_mean_squared_error: 1.8811 - val_y2_output_root_mean_squared_error: 2.4824
# Epoch 41/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.2775 - y1_output_loss: 3.4233 - y2_output_loss: 6.7668 - y1_output_root_mean_squared_error: 1.8581 - y2_output_root_mean_squared_error: 2.6125 - val_loss: 8.3330 - val_y1_output_loss: 3.2003 - val_y2_output_loss: 5.2894 - val_y1_output_root_mean_squared_error: 1.7570 - val_y2_output_root_mean_squared_error: 2.2904
# Epoch 42/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.4124 - y1_output_loss: 2.7515 - y2_output_loss: 5.6550 - y1_output_root_mean_squared_error: 1.6657 - y2_output_root_mean_squared_error: 2.3744 - val_loss: 9.5578 - val_y1_output_loss: 3.1045 - val_y2_output_loss: 6.6475 - val_y1_output_root_mean_squared_error: 1.7285 - val_y2_output_root_mean_squared_error: 2.5632
# Epoch 43/500
# 614/614 [==============================] - 0s 145us/sample - loss: 7.1497 - y1_output_loss: 2.4437 - y2_output_loss: 4.6733 - y1_output_root_mean_squared_error: 1.5599 - y2_output_root_mean_squared_error: 2.1717 - val_loss: 7.9633 - val_y1_output_loss: 2.9957 - val_y2_output_loss: 5.1504 - val_y1_output_root_mean_squared_error: 1.6924 - val_y2_output_root_mean_squared_error: 2.2581
# Epoch 44/500
# 614/614 [==============================] - 0s 143us/sample - loss: 7.1742 - y1_output_loss: 2.5407 - y2_output_loss: 4.7397 - y1_output_root_mean_squared_error: 1.5844 - y2_output_root_mean_squared_error: 2.1596 - val_loss: 7.8275 - val_y1_output_loss: 2.8805 - val_y2_output_loss: 5.1611 - val_y1_output_root_mean_squared_error: 1.6756 - val_y2_output_root_mean_squared_error: 2.2405
# Epoch 45/500
# 614/614 [==============================] - 0s 144us/sample - loss: 9.0517 - y1_output_loss: 2.7065 - y2_output_loss: 6.2680 - y1_output_root_mean_squared_error: 1.6523 - y2_output_root_mean_squared_error: 2.5143 - val_loss: 16.2606 - val_y1_output_loss: 4.7439 - val_y2_output_loss: 11.8388 - val_y1_output_root_mean_squared_error: 2.1659 - val_y2_output_root_mean_squared_error: 3.4014
# Epoch 46/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.6309 - y1_output_loss: 2.5789 - y2_output_loss: 4.9842 - y1_output_root_mean_squared_error: 1.6128 - y2_output_root_mean_squared_error: 2.2427 - val_loss: 6.5576 - val_y1_output_loss: 2.2450 - val_y2_output_loss: 4.5046 - val_y1_output_root_mean_squared_error: 1.4682 - val_y2_output_root_mean_squared_error: 2.0981
# Epoch 47/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.6925 - y1_output_loss: 2.5183 - y2_output_loss: 5.1059 - y1_output_root_mean_squared_error: 1.5940 - y2_output_root_mean_squared_error: 2.2697 - val_loss: 8.8868 - val_y1_output_loss: 2.9109 - val_y2_output_loss: 6.0668 - val_y1_output_root_mean_squared_error: 1.6770 - val_y2_output_root_mean_squared_error: 2.4646
# Epoch 48/500
# 614/614 [==============================] - 0s 141us/sample - loss: 5.7667 - y1_output_loss: 1.8448 - y2_output_loss: 3.9251 - y1_output_root_mean_squared_error: 1.3624 - y2_output_root_mean_squared_error: 1.9775 - val_loss: 13.9433 - val_y1_output_loss: 3.6044 - val_y2_output_loss: 10.2789 - val_y1_output_root_mean_squared_error: 1.8745 - val_y2_output_root_mean_squared_error: 3.2295
# Epoch 49/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.9905 - y1_output_loss: 2.2946 - y2_output_loss: 5.6725 - y1_output_root_mean_squared_error: 1.5207 - y2_output_root_mean_squared_error: 2.3828 - val_loss: 6.8425 - val_y1_output_loss: 2.2820 - val_y2_output_loss: 4.6417 - val_y1_output_root_mean_squared_error: 1.4766 - val_y2_output_root_mean_squared_error: 2.1592
# Epoch 50/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.9910 - y1_output_loss: 2.2662 - y2_output_loss: 4.7349 - y1_output_root_mean_squared_error: 1.5006 - y2_output_root_mean_squared_error: 2.1770 - val_loss: 7.1372 - val_y1_output_loss: 2.4308 - val_y2_output_loss: 4.9870 - val_y1_output_root_mean_squared_error: 1.5232 - val_y2_output_root_mean_squared_error: 2.1948
# Epoch 51/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.9337 - y1_output_loss: 2.1970 - y2_output_loss: 4.7015 - y1_output_root_mean_squared_error: 1.4830 - y2_output_root_mean_squared_error: 2.1759 - val_loss: 7.2807 - val_y1_output_loss: 2.3030 - val_y2_output_loss: 5.2973 - val_y1_output_root_mean_squared_error: 1.4712 - val_y2_output_root_mean_squared_error: 2.2619
# Epoch 52/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.8800 - y1_output_loss: 2.2557 - y2_output_loss: 4.6115 - y1_output_root_mean_squared_error: 1.5051 - y2_output_root_mean_squared_error: 2.1482 - val_loss: 6.9077 - val_y1_output_loss: 2.0198 - val_y2_output_loss: 5.1598 - val_y1_output_root_mean_squared_error: 1.3839 - val_y2_output_root_mean_squared_error: 2.2344
# Epoch 53/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.0858 - y1_output_loss: 2.1323 - y2_output_loss: 4.9444 - y1_output_root_mean_squared_error: 1.4651 - y2_output_root_mean_squared_error: 2.2224 - val_loss: 8.2787 - val_y1_output_loss: 2.1238 - val_y2_output_loss: 6.5240 - val_y1_output_root_mean_squared_error: 1.4231 - val_y2_output_root_mean_squared_error: 2.5007
# Epoch 54/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.7828 - y1_output_loss: 2.0761 - y2_output_loss: 4.6777 - y1_output_root_mean_squared_error: 1.4355 - y2_output_root_mean_squared_error: 2.1730 - val_loss: 6.4510 - val_y1_output_loss: 2.3004 - val_y2_output_loss: 4.5036 - val_y1_output_root_mean_squared_error: 1.4482 - val_y2_output_root_mean_squared_error: 2.0866
# Epoch 55/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.8851 - y1_output_loss: 1.7500 - y2_output_loss: 4.1271 - y1_output_root_mean_squared_error: 1.3251 - y2_output_root_mean_squared_error: 2.0320 - val_loss: 11.5963 - val_y1_output_loss: 4.2143 - val_y2_output_loss: 7.3209 - val_y1_output_root_mean_squared_error: 2.0250 - val_y2_output_root_mean_squared_error: 2.7378
# Epoch 56/500
# 614/614 [==============================] - 0s 144us/sample - loss: 5.8699 - y1_output_loss: 1.8267 - y2_output_loss: 4.1277 - y1_output_root_mean_squared_error: 1.3384 - y2_output_root_mean_squared_error: 2.0196 - val_loss: 22.7260 - val_y1_output_loss: 5.2808 - val_y2_output_loss: 18.1744 - val_y1_output_root_mean_squared_error: 2.2703 - val_y2_output_root_mean_squared_error: 4.1918
# Epoch 57/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.1015 - y1_output_loss: 1.7863 - y2_output_loss: 4.2780 - y1_output_root_mean_squared_error: 1.3414 - y2_output_root_mean_squared_error: 2.0742 - val_loss: 6.9315 - val_y1_output_loss: 2.3703 - val_y2_output_loss: 4.5754 - val_y1_output_root_mean_squared_error: 1.5285 - val_y2_output_root_mean_squared_error: 2.1436
# Epoch 58/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.2032 - y1_output_loss: 1.9186 - y2_output_loss: 4.2294 - y1_output_root_mean_squared_error: 1.3914 - y2_output_root_mean_squared_error: 2.0657 - val_loss: 5.2916 - val_y1_output_loss: 1.7735 - val_y2_output_loss: 3.5934 - val_y1_output_root_mean_squared_error: 1.3030 - val_y2_output_root_mean_squared_error: 1.8957
# Epoch 59/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.0370 - y1_output_loss: 1.6484 - y2_output_loss: 4.3686 - y1_output_root_mean_squared_error: 1.2847 - y2_output_root_mean_squared_error: 2.0944 - val_loss: 5.4080 - val_y1_output_loss: 1.7830 - val_y2_output_loss: 3.6727 - val_y1_output_root_mean_squared_error: 1.3238 - val_y2_output_root_mean_squared_error: 1.9119
# Epoch 60/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.7007 - y1_output_loss: 1.4073 - y2_output_loss: 3.3158 - y1_output_root_mean_squared_error: 1.1893 - y2_output_root_mean_squared_error: 1.8128 - val_loss: 10.3565 - val_y1_output_loss: 3.3981 - val_y2_output_loss: 6.8528 - val_y1_output_root_mean_squared_error: 1.8277 - val_y2_output_root_mean_squared_error: 2.6488
# Epoch 61/500
# 614/614 [==============================] - 0s 143us/sample - loss: 6.4055 - y1_output_loss: 1.7864 - y2_output_loss: 4.5676 - y1_output_root_mean_squared_error: 1.3422 - y2_output_root_mean_squared_error: 2.1457 - val_loss: 14.5282 - val_y1_output_loss: 3.7969 - val_y2_output_loss: 11.0911 - val_y1_output_root_mean_squared_error: 1.9320 - val_y2_output_root_mean_squared_error: 3.2857
# Epoch 62/500
# 614/614 [==============================] - 0s 146us/sample - loss: 6.4962 - y1_output_loss: 1.6367 - y2_output_loss: 4.8516 - y1_output_root_mean_squared_error: 1.2847 - y2_output_root_mean_squared_error: 2.2013 - val_loss: 10.9824 - val_y1_output_loss: 2.6408 - val_y2_output_loss: 8.1755 - val_y1_output_root_mean_squared_error: 1.6131 - val_y2_output_root_mean_squared_error: 2.8949
# Epoch 63/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.7602 - y1_output_loss: 1.4474 - y2_output_loss: 3.2858 - y1_output_root_mean_squared_error: 1.2071 - y2_output_root_mean_squared_error: 1.8174 - val_loss: 7.1246 - val_y1_output_loss: 1.9688 - val_y2_output_loss: 5.4250 - val_y1_output_root_mean_squared_error: 1.3851 - val_y2_output_root_mean_squared_error: 2.2817
# Epoch 64/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.3412 - y1_output_loss: 1.7509 - y2_output_loss: 4.5919 - y1_output_root_mean_squared_error: 1.3277 - y2_output_root_mean_squared_error: 2.1397 - val_loss: 9.7625 - val_y1_output_loss: 1.7828 - val_y2_output_loss: 7.8530 - val_y1_output_root_mean_squared_error: 1.3220 - val_y2_output_root_mean_squared_error: 2.8311
# Epoch 65/500
# 614/614 [==============================] - 0s 149us/sample - loss: 8.9507 - y1_output_loss: 2.6862 - y2_output_loss: 6.1891 - y1_output_root_mean_squared_error: 1.6468 - y2_output_root_mean_squared_error: 2.4978 - val_loss: 5.4200 - val_y1_output_loss: 1.5465 - val_y2_output_loss: 4.0177 - val_y1_output_root_mean_squared_error: 1.2237 - val_y2_output_root_mean_squared_error: 1.9806
# Epoch 66/500
# 614/614 [==============================] - 0s 147us/sample - loss: 4.2575 - y1_output_loss: 1.1928 - y2_output_loss: 3.0482 - y1_output_root_mean_squared_error: 1.0939 - y2_output_root_mean_squared_error: 1.7495 - val_loss: 6.4792 - val_y1_output_loss: 1.3761 - val_y2_output_loss: 5.2692 - val_y1_output_root_mean_squared_error: 1.1615 - val_y2_output_root_mean_squared_error: 2.2650
# Epoch 67/500
# 614/614 [==============================] - 0s 140us/sample - loss: 15.7186 - y1_output_loss: 4.9979 - y2_output_loss: 10.6065 - y1_output_root_mean_squared_error: 2.2393 - y2_output_root_mean_squared_error: 3.2717 - val_loss: 6.7643 - val_y1_output_loss: 2.9887 - val_y2_output_loss: 3.9578 - val_y1_output_root_mean_squared_error: 1.6853 - val_y2_output_root_mean_squared_error: 1.9809
# Epoch 68/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.1248 - y1_output_loss: 1.4115 - y2_output_loss: 3.7538 - y1_output_root_mean_squared_error: 1.1757 - y2_output_root_mean_squared_error: 1.9345 - val_loss: 10.2053 - val_y1_output_loss: 3.9875 - val_y2_output_loss: 6.5108 - val_y1_output_root_mean_squared_error: 1.9602 - val_y2_output_root_mean_squared_error: 2.5225
# Epoch 69/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.8155 - y1_output_loss: 1.4342 - y2_output_loss: 3.4410 - y1_output_root_mean_squared_error: 1.1994 - y2_output_root_mean_squared_error: 1.8376 - val_loss: 9.1678 - val_y1_output_loss: 2.5065 - val_y2_output_loss: 6.7474 - val_y1_output_root_mean_squared_error: 1.5462 - val_y2_output_root_mean_squared_error: 2.6033
# Epoch 70/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.6359 - y1_output_loss: 1.3187 - y2_output_loss: 3.3058 - y1_output_root_mean_squared_error: 1.1519 - y2_output_root_mean_squared_error: 1.8191 - val_loss: 11.1768 - val_y1_output_loss: 3.2119 - val_y2_output_loss: 7.8490 - val_y1_output_root_mean_squared_error: 1.7725 - val_y2_output_root_mean_squared_error: 2.8346
# Epoch 71/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.4353 - y1_output_loss: 1.4015 - y2_output_loss: 3.9881 - y1_output_root_mean_squared_error: 1.1880 - y2_output_root_mean_squared_error: 2.0060 - val_loss: 5.4463 - val_y1_output_loss: 1.1656 - val_y2_output_loss: 4.2458 - val_y1_output_root_mean_squared_error: 1.0627 - val_y2_output_root_mean_squared_error: 2.0777
# Epoch 72/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.3766 - y1_output_loss: 1.1402 - y2_output_loss: 3.2756 - y1_output_root_mean_squared_error: 1.0579 - y2_output_root_mean_squared_error: 1.8049 - val_loss: 7.5486 - val_y1_output_loss: 2.7687 - val_y2_output_loss: 5.2980 - val_y1_output_root_mean_squared_error: 1.5684 - val_y2_output_root_mean_squared_error: 2.2558
# Epoch 73/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.5295 - y1_output_loss: 1.2093 - y2_output_loss: 3.3003 - y1_output_root_mean_squared_error: 1.1036 - y2_output_root_mean_squared_error: 1.8198 - val_loss: 4.5639 - val_y1_output_loss: 1.1026 - val_y2_output_loss: 3.6745 - val_y1_output_root_mean_squared_error: 1.0066 - val_y2_output_root_mean_squared_error: 1.8843
# Epoch 74/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.8147 - y1_output_loss: 1.0512 - y2_output_loss: 2.7516 - y1_output_root_mean_squared_error: 1.0287 - y2_output_root_mean_squared_error: 1.6603 - val_loss: 6.5877 - val_y1_output_loss: 1.7027 - val_y2_output_loss: 4.8598 - val_y1_output_root_mean_squared_error: 1.2792 - val_y2_output_root_mean_squared_error: 2.2252
# Epoch 75/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.6737 - y1_output_loss: 1.1091 - y2_output_loss: 2.5331 - y1_output_root_mean_squared_error: 1.0580 - y2_output_root_mean_squared_error: 1.5982 - val_loss: 3.8761 - val_y1_output_loss: 0.9244 - val_y2_output_loss: 2.9737 - val_y1_output_root_mean_squared_error: 0.9441 - val_y2_output_root_mean_squared_error: 1.7277
# Epoch 76/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.8331 - y1_output_loss: 1.0949 - y2_output_loss: 2.7071 - y1_output_root_mean_squared_error: 1.0497 - y2_output_root_mean_squared_error: 1.6527 - val_loss: 3.9371 - val_y1_output_loss: 0.9402 - val_y2_output_loss: 3.0346 - val_y1_output_root_mean_squared_error: 0.9542 - val_y2_output_root_mean_squared_error: 1.7397
# Epoch 77/500
# 614/614 [==============================] - 0s 143us/sample - loss: 5.4331 - y1_output_loss: 1.4719 - y2_output_loss: 3.9387 - y1_output_root_mean_squared_error: 1.2169 - y2_output_root_mean_squared_error: 1.9881 - val_loss: 4.6317 - val_y1_output_loss: 1.2685 - val_y2_output_loss: 3.4101 - val_y1_output_root_mean_squared_error: 1.1069 - val_y2_output_root_mean_squared_error: 1.8457
# Epoch 78/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.8286 - y1_output_loss: 0.9791 - y2_output_loss: 2.8366 - y1_output_root_mean_squared_error: 0.9881 - y2_output_root_mean_squared_error: 1.6888 - val_loss: 6.2301 - val_y1_output_loss: 1.8290 - val_y2_output_loss: 4.5107 - val_y1_output_root_mean_squared_error: 1.3524 - val_y2_output_root_mean_squared_error: 2.0979
# Epoch 79/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.5064 - y1_output_loss: 0.9798 - y2_output_loss: 2.5156 - y1_output_root_mean_squared_error: 0.9838 - y2_output_root_mean_squared_error: 1.5933 - val_loss: 3.7330 - val_y1_output_loss: 0.8970 - val_y2_output_loss: 2.8334 - val_y1_output_root_mean_squared_error: 0.9261 - val_y2_output_root_mean_squared_error: 1.6957
# Epoch 80/500
# 614/614 [==============================] - 0s 147us/sample - loss: 26.2088 - y1_output_loss: 9.1470 - y2_output_loss: 16.8274 - y1_output_root_mean_squared_error: 3.0379 - y2_output_root_mean_squared_error: 4.1207 - val_loss: 7.0973 - val_y1_output_loss: 2.4550 - val_y2_output_loss: 4.8401 - val_y1_output_root_mean_squared_error: 1.5420 - val_y2_output_root_mean_squared_error: 2.1725
# Epoch 81/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.7561 - y1_output_loss: 1.0068 - y2_output_loss: 2.7665 - y1_output_root_mean_squared_error: 0.9895 - y2_output_root_mean_squared_error: 1.6664 - val_loss: 16.0508 - val_y1_output_loss: 7.1384 - val_y2_output_loss: 9.5857 - val_y1_output_root_mean_squared_error: 2.6126 - val_y2_output_root_mean_squared_error: 3.0373
# Epoch 82/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.2811 - y1_output_loss: 1.0771 - y2_output_loss: 3.1679 - y1_output_root_mean_squared_error: 1.0416 - y2_output_root_mean_squared_error: 1.7878 - val_loss: 4.0736 - val_y1_output_loss: 1.0116 - val_y2_output_loss: 3.0915 - val_y1_output_root_mean_squared_error: 0.9969 - val_y2_output_root_mean_squared_error: 1.7549
# Epoch 83/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.2890 - y1_output_loss: 0.8470 - y2_output_loss: 2.4176 - y1_output_root_mean_squared_error: 0.9244 - y2_output_root_mean_squared_error: 1.5603 - val_loss: 4.7056 - val_y1_output_loss: 0.8556 - val_y2_output_loss: 3.7940 - val_y1_output_root_mean_squared_error: 0.9083 - val_y2_output_root_mean_squared_error: 1.9699
# Epoch 84/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.1909 - y1_output_loss: 1.0249 - y2_output_loss: 3.1480 - y1_output_root_mean_squared_error: 1.0151 - y2_output_root_mean_squared_error: 1.7777 - val_loss: 6.8012 - val_y1_output_loss: 1.5053 - val_y2_output_loss: 5.4950 - val_y1_output_root_mean_squared_error: 1.2228 - val_y2_output_root_mean_squared_error: 2.3035
# Epoch 85/500
# 614/614 [==============================] - 0s 150us/sample - loss: 4.1880 - y1_output_loss: 0.9810 - y2_output_loss: 3.2230 - y1_output_root_mean_squared_error: 0.9868 - y2_output_root_mean_squared_error: 1.7928 - val_loss: 5.3843 - val_y1_output_loss: 1.1644 - val_y2_output_loss: 4.2773 - val_y1_output_root_mean_squared_error: 1.0722 - val_y2_output_root_mean_squared_error: 2.0579
# Epoch 86/500
# 614/614 [==============================] - 0s 151us/sample - loss: 3.3587 - y1_output_loss: 0.8653 - y2_output_loss: 2.4740 - y1_output_root_mean_squared_error: 0.9309 - y2_output_root_mean_squared_error: 1.5787 - val_loss: 4.1644 - val_y1_output_loss: 1.0018 - val_y2_output_loss: 3.2830 - val_y1_output_root_mean_squared_error: 0.9802 - val_y2_output_root_mean_squared_error: 1.7898
# Epoch 87/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.7410 - y1_output_loss: 0.6375 - y2_output_loss: 2.0858 - y1_output_root_mean_squared_error: 0.8012 - y2_output_root_mean_squared_error: 1.4488 - val_loss: 3.2355 - val_y1_output_loss: 0.6602 - val_y2_output_loss: 2.5349 - val_y1_output_root_mean_squared_error: 0.8094 - val_y2_output_root_mean_squared_error: 1.6063
# Epoch 88/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.1518 - y1_output_loss: 0.9952 - y2_output_loss: 3.1169 - y1_output_root_mean_squared_error: 1.0023 - y2_output_root_mean_squared_error: 1.7740 - val_loss: 3.1176 - val_y1_output_loss: 0.6186 - val_y2_output_loss: 2.5130 - val_y1_output_root_mean_squared_error: 0.7835 - val_y2_output_root_mean_squared_error: 1.5823
# Epoch 89/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.6381 - y1_output_loss: 0.9584 - y2_output_loss: 2.6742 - y1_output_root_mean_squared_error: 0.9835 - y2_output_root_mean_squared_error: 1.6342 - val_loss: 3.3357 - val_y1_output_loss: 0.5689 - val_y2_output_loss: 2.7133 - val_y1_output_root_mean_squared_error: 0.7517 - val_y2_output_root_mean_squared_error: 1.6645
# Epoch 90/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.5232 - y1_output_loss: 0.5825 - y2_output_loss: 1.9279 - y1_output_root_mean_squared_error: 0.7640 - y2_output_root_mean_squared_error: 1.3927 - val_loss: 4.1010 - val_y1_output_loss: 0.7907 - val_y2_output_loss: 3.3474 - val_y1_output_root_mean_squared_error: 0.8938 - val_y2_output_root_mean_squared_error: 1.8172
# Epoch 91/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.7586 - y1_output_loss: 0.9746 - y2_output_loss: 2.7539 - y1_output_root_mean_squared_error: 0.9919 - y2_output_root_mean_squared_error: 1.6657 - val_loss: 3.2623 - val_y1_output_loss: 0.6094 - val_y2_output_loss: 2.6652 - val_y1_output_root_mean_squared_error: 0.7802 - val_y2_output_root_mean_squared_error: 1.6290
# Epoch 92/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.2974 - y1_output_loss: 0.8028 - y2_output_loss: 2.4748 - y1_output_root_mean_squared_error: 0.8988 - y2_output_root_mean_squared_error: 1.5778 - val_loss: 4.3270 - val_y1_output_loss: 1.3499 - val_y2_output_loss: 2.9336 - val_y1_output_root_mean_squared_error: 1.1621 - val_y2_output_root_mean_squared_error: 1.7253
# Epoch 93/500
# 614/614 [==============================] - 0s 144us/sample - loss: 4.7571 - y1_output_loss: 1.3907 - y2_output_loss: 3.3760 - y1_output_root_mean_squared_error: 1.1809 - y2_output_root_mean_squared_error: 1.8337 - val_loss: 4.6411 - val_y1_output_loss: 0.9826 - val_y2_output_loss: 3.7457 - val_y1_output_root_mean_squared_error: 0.9882 - val_y2_output_root_mean_squared_error: 1.9143
# Epoch 94/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.6869 - y1_output_loss: 0.6785 - y2_output_loss: 2.0265 - y1_output_root_mean_squared_error: 0.8241 - y2_output_root_mean_squared_error: 1.4169 - val_loss: 5.5084 - val_y1_output_loss: 0.8546 - val_y2_output_loss: 4.6481 - val_y1_output_root_mean_squared_error: 0.9022 - val_y2_output_root_mean_squared_error: 2.1667
# Epoch 95/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.3112 - y1_output_loss: 0.5147 - y2_output_loss: 1.7808 - y1_output_root_mean_squared_error: 0.7201 - y2_output_root_mean_squared_error: 1.3389 - val_loss: 3.8364 - val_y1_output_loss: 0.6709 - val_y2_output_loss: 3.2102 - val_y1_output_root_mean_squared_error: 0.8235 - val_y2_output_root_mean_squared_error: 1.7771
# Epoch 96/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.6136 - y1_output_loss: 0.6263 - y2_output_loss: 2.0012 - y1_output_root_mean_squared_error: 0.7919 - y2_output_root_mean_squared_error: 1.4095 - val_loss: 3.2364 - val_y1_output_loss: 0.6293 - val_y2_output_loss: 2.5867 - val_y1_output_root_mean_squared_error: 0.7748 - val_y2_output_root_mean_squared_error: 1.6236
# Epoch 97/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5876 - y1_output_loss: 0.5434 - y2_output_loss: 2.0378 - y1_output_root_mean_squared_error: 0.7330 - y2_output_root_mean_squared_error: 1.4319 - val_loss: 3.1259 - val_y1_output_loss: 0.5488 - val_y2_output_loss: 2.5880 - val_y1_output_root_mean_squared_error: 0.7407 - val_y2_output_root_mean_squared_error: 1.6054
# Epoch 98/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.4419 - y1_output_loss: 0.6071 - y2_output_loss: 1.8399 - y1_output_root_mean_squared_error: 0.7668 - y2_output_root_mean_squared_error: 1.3616 - val_loss: 3.3058 - val_y1_output_loss: 0.6497 - val_y2_output_loss: 2.6374 - val_y1_output_root_mean_squared_error: 0.8063 - val_y2_output_root_mean_squared_error: 1.6296
# Epoch 99/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5446 - y1_output_loss: 0.5108 - y2_output_loss: 2.0610 - y1_output_root_mean_squared_error: 0.7155 - y2_output_root_mean_squared_error: 1.4257 - val_loss: 6.3747 - val_y1_output_loss: 0.6836 - val_y2_output_loss: 5.8140 - val_y1_output_root_mean_squared_error: 0.8223 - val_y2_output_root_mean_squared_error: 2.3872
# Epoch 100/500
# 614/614 [==============================] - 0s 148us/sample - loss: 3.3918 - y1_output_loss: 0.7505 - y2_output_loss: 2.6561 - y1_output_root_mean_squared_error: 0.8704 - y2_output_root_mean_squared_error: 1.6230 - val_loss: 8.5498 - val_y1_output_loss: 1.2295 - val_y2_output_loss: 7.1967 - val_y1_output_root_mean_squared_error: 1.1042 - val_y2_output_root_mean_squared_error: 2.7075
# Epoch 101/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.1501 - y1_output_loss: 1.0673 - y2_output_loss: 3.0697 - y1_output_root_mean_squared_error: 1.0362 - y2_output_root_mean_squared_error: 1.7540 - val_loss: 3.8704 - val_y1_output_loss: 0.5811 - val_y2_output_loss: 3.3024 - val_y1_output_root_mean_squared_error: 0.7677 - val_y2_output_root_mean_squared_error: 1.8114
# Epoch 102/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.5131 - y1_output_loss: 0.5484 - y2_output_loss: 1.9933 - y1_output_root_mean_squared_error: 0.7403 - y2_output_root_mean_squared_error: 1.4018 - val_loss: 5.0874 - val_y1_output_loss: 1.2469 - val_y2_output_loss: 3.8660 - val_y1_output_root_mean_squared_error: 1.0985 - val_y2_output_root_mean_squared_error: 1.9699
# Epoch 103/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.9126 - y1_output_loss: 0.6581 - y2_output_loss: 2.2309 - y1_output_root_mean_squared_error: 0.8148 - y2_output_root_mean_squared_error: 1.4996 - val_loss: 2.7533 - val_y1_output_loss: 0.5614 - val_y2_output_loss: 2.1424 - val_y1_output_root_mean_squared_error: 0.7472 - val_y2_output_root_mean_squared_error: 1.4815
# Epoch 104/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.8361 - y1_output_loss: 0.7203 - y2_output_loss: 2.1016 - y1_output_root_mean_squared_error: 0.8515 - y2_output_root_mean_squared_error: 1.4530 - val_loss: 3.1090 - val_y1_output_loss: 0.6642 - val_y2_output_loss: 2.4193 - val_y1_output_root_mean_squared_error: 0.8094 - val_y2_output_root_mean_squared_error: 1.5665
# Epoch 105/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.2633 - y1_output_loss: 0.5359 - y2_output_loss: 1.7106 - y1_output_root_mean_squared_error: 0.7345 - y2_output_root_mean_squared_error: 1.3129 - val_loss: 2.8161 - val_y1_output_loss: 0.5120 - val_y2_output_loss: 2.2930 - val_y1_output_root_mean_squared_error: 0.7017 - val_y2_output_root_mean_squared_error: 1.5244
# Epoch 106/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.2330 - y1_output_loss: 0.7400 - y2_output_loss: 2.4744 - y1_output_root_mean_squared_error: 0.8641 - y2_output_root_mean_squared_error: 1.5768 - val_loss: 2.9834 - val_y1_output_loss: 0.5015 - val_y2_output_loss: 2.4552 - val_y1_output_root_mean_squared_error: 0.7137 - val_y2_output_root_mean_squared_error: 1.5729
# Epoch 107/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1223 - y1_output_loss: 0.8183 - y2_output_loss: 2.2775 - y1_output_root_mean_squared_error: 0.9086 - y2_output_root_mean_squared_error: 1.5155 - val_loss: 2.8736 - val_y1_output_loss: 0.5358 - val_y2_output_loss: 2.2936 - val_y1_output_root_mean_squared_error: 0.7252 - val_y2_output_root_mean_squared_error: 1.5322
# Epoch 108/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.2208 - y1_output_loss: 0.4520 - y2_output_loss: 1.7796 - y1_output_root_mean_squared_error: 0.6734 - y2_output_root_mean_squared_error: 1.3294 - val_loss: 2.9360 - val_y1_output_loss: 0.5481 - val_y2_output_loss: 2.3363 - val_y1_output_root_mean_squared_error: 0.7376 - val_y2_output_root_mean_squared_error: 1.5466
# Epoch 109/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.7650 - y1_output_loss: 0.6886 - y2_output_loss: 2.1307 - y1_output_root_mean_squared_error: 0.8307 - y2_output_root_mean_squared_error: 1.4405 - val_loss: 15.6296 - val_y1_output_loss: 4.1155 - val_y2_output_loss: 11.7542 - val_y1_output_root_mean_squared_error: 2.0211 - val_y2_output_root_mean_squared_error: 3.3977
# Epoch 110/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.2585 - y1_output_loss: 0.4569 - y2_output_loss: 1.8247 - y1_output_root_mean_squared_error: 0.6783 - y2_output_root_mean_squared_error: 1.3410 - val_loss: 3.9041 - val_y1_output_loss: 0.9483 - val_y2_output_loss: 2.9962 - val_y1_output_root_mean_squared_error: 0.9470 - val_y2_output_root_mean_squared_error: 1.7341
# Epoch 111/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.1197 - y1_output_loss: 1.2967 - y2_output_loss: 2.7940 - y1_output_root_mean_squared_error: 1.1435 - y2_output_root_mean_squared_error: 1.6770 - val_loss: 2.7744 - val_y1_output_loss: 0.5905 - val_y2_output_loss: 2.1749 - val_y1_output_root_mean_squared_error: 0.7553 - val_y2_output_root_mean_squared_error: 1.4845
# Epoch 112/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.9820 - y1_output_loss: 0.7045 - y2_output_loss: 2.2771 - y1_output_root_mean_squared_error: 0.8368 - y2_output_root_mean_squared_error: 1.5106 - val_loss: 3.7203 - val_y1_output_loss: 1.3032 - val_y2_output_loss: 2.3645 - val_y1_output_root_mean_squared_error: 1.1336 - val_y2_output_root_mean_squared_error: 1.5605
# Epoch 113/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.4684 - y1_output_loss: 0.4798 - y2_output_loss: 1.9885 - y1_output_root_mean_squared_error: 0.6942 - y2_output_root_mean_squared_error: 1.4094 - val_loss: 6.1915 - val_y1_output_loss: 0.7179 - val_y2_output_loss: 5.4844 - val_y1_output_root_mean_squared_error: 0.8193 - val_y2_output_root_mean_squared_error: 2.3495
# Epoch 114/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.5177 - y1_output_loss: 0.5394 - y2_output_loss: 1.9657 - y1_output_root_mean_squared_error: 0.7335 - y2_output_root_mean_squared_error: 1.4070 - val_loss: 6.4972 - val_y1_output_loss: 1.3793 - val_y2_output_loss: 5.1585 - val_y1_output_root_mean_squared_error: 1.1548 - val_y2_output_root_mean_squared_error: 2.2724
# Epoch 115/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.4088 - y1_output_loss: 0.5737 - y2_output_loss: 1.8216 - y1_output_root_mean_squared_error: 0.7595 - y2_output_root_mean_squared_error: 1.3535 - val_loss: 2.5847 - val_y1_output_loss: 0.5493 - val_y2_output_loss: 1.9797 - val_y1_output_root_mean_squared_error: 0.7344 - val_y2_output_root_mean_squared_error: 1.4301
# Epoch 116/500
# 614/614 [==============================] - 0s 145us/sample - loss: 3.3911 - y1_output_loss: 1.0706 - y2_output_loss: 2.2949 - y1_output_root_mean_squared_error: 1.0388 - y2_output_root_mean_squared_error: 1.5205 - val_loss: 8.5175 - val_y1_output_loss: 3.4820 - val_y2_output_loss: 5.1733 - val_y1_output_root_mean_squared_error: 1.8380 - val_y2_output_root_mean_squared_error: 2.2670
# Epoch 117/500
# 614/614 [==============================] - 0s 142us/sample - loss: 4.0876 - y1_output_loss: 1.1441 - y2_output_loss: 2.9194 - y1_output_root_mean_squared_error: 1.0745 - y2_output_root_mean_squared_error: 1.7126 - val_loss: 4.2724 - val_y1_output_loss: 0.9806 - val_y2_output_loss: 3.2582 - val_y1_output_root_mean_squared_error: 0.9903 - val_y2_output_root_mean_squared_error: 1.8143
# Epoch 118/500
# 614/614 [==============================] - 0s 149us/sample - loss: 2.8863 - y1_output_loss: 0.6428 - y2_output_loss: 2.2234 - y1_output_root_mean_squared_error: 0.8054 - y2_output_root_mean_squared_error: 1.4959 - val_loss: 4.5128 - val_y1_output_loss: 1.1167 - val_y2_output_loss: 3.3872 - val_y1_output_root_mean_squared_error: 1.0558 - val_y2_output_root_mean_squared_error: 1.8434
# Epoch 119/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.5212 - y1_output_loss: 0.6271 - y2_output_loss: 1.8998 - y1_output_root_mean_squared_error: 0.7925 - y2_output_root_mean_squared_error: 1.3760 - val_loss: 2.7693 - val_y1_output_loss: 0.6010 - val_y2_output_loss: 2.1121 - val_y1_output_root_mean_squared_error: 0.7751 - val_y2_output_root_mean_squared_error: 1.4726
# Epoch 120/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.4849 - y1_output_loss: 0.6016 - y2_output_loss: 1.8650 - y1_output_root_mean_squared_error: 0.7781 - y2_output_root_mean_squared_error: 1.3709 - val_loss: 2.5620 - val_y1_output_loss: 0.4375 - val_y2_output_loss: 2.0928 - val_y1_output_root_mean_squared_error: 0.6585 - val_y2_output_root_mean_squared_error: 1.4589
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3355 - y1_output_loss: 0.1142 - y2_output_loss: 0.2211 - y1_output_root_mean_squared_error: 0.3381 - y2_output_root_mean_squared_error: 0.4703 - val_loss: 1.1265 - val_y1_output_loss: 0.2151 - val_y2_output_loss: 0.8784 - val_y1_output_root_mean_squared_error: 0.4672 - val_y2_output_root_mean_squared_error: 0.9530
# Epoch 462/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4087 - y1_output_loss: 0.1383 - y2_output_loss: 0.2726 - y1_output_root_mean_squared_error: 0.3733 - y2_output_root_mean_squared_error: 0.5189 - val_loss: 1.1358 - val_y1_output_loss: 0.1961 - val_y2_output_loss: 0.9046 - val_y1_output_root_mean_squared_error: 0.4479 - val_y2_output_root_mean_squared_error: 0.9671
# Epoch 463/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3857 - y1_output_loss: 0.1285 - y2_output_loss: 0.2565 - y1_output_root_mean_squared_error: 0.3574 - y2_output_root_mean_squared_error: 0.5079 - val_loss: 1.0843 - val_y1_output_loss: 0.2587 - val_y2_output_loss: 0.8079 - val_y1_output_root_mean_squared_error: 0.5028 - val_y2_output_root_mean_squared_error: 0.9119
# Epoch 464/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3845 - y1_output_loss: 0.1378 - y2_output_loss: 0.2462 - y1_output_root_mean_squared_error: 0.3718 - y2_output_root_mean_squared_error: 0.4962 - val_loss: 1.2486 - val_y1_output_loss: 0.2845 - val_y2_output_loss: 0.9493 - val_y1_output_root_mean_squared_error: 0.5328 - val_y2_output_root_mean_squared_error: 0.9822
# Epoch 465/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3279 - y1_output_loss: 0.1103 - y2_output_loss: 0.2209 - y1_output_root_mean_squared_error: 0.3323 - y2_output_root_mean_squared_error: 0.4663 - val_loss: 2.3209 - val_y1_output_loss: 0.3286 - val_y2_output_loss: 2.0012 - val_y1_output_root_mean_squared_error: 0.5744 - val_y2_output_root_mean_squared_error: 1.4110
# Epoch 466/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3224 - y1_output_loss: 0.1090 - y2_output_loss: 0.2258 - y1_output_root_mean_squared_error: 0.3295 - y2_output_root_mean_squared_error: 0.4625 - val_loss: 3.4742 - val_y1_output_loss: 0.3545 - val_y2_output_loss: 3.1876 - val_y1_output_root_mean_squared_error: 0.5898 - val_y2_output_root_mean_squared_error: 1.7681
# Epoch 467/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.4816 - y1_output_loss: 0.1387 - y2_output_loss: 0.3415 - y1_output_root_mean_squared_error: 0.3736 - y2_output_root_mean_squared_error: 0.5848 - val_loss: 1.1298 - val_y1_output_loss: 0.2354 - val_y2_output_loss: 0.8643 - val_y1_output_root_mean_squared_error: 0.4837 - val_y2_output_root_mean_squared_error: 0.9465
# Epoch 468/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.4037 - y1_output_loss: 0.1177 - y2_output_loss: 0.2838 - y1_output_root_mean_squared_error: 0.3442 - y2_output_root_mean_squared_error: 0.5340 - val_loss: 1.1742 - val_y1_output_loss: 0.2211 - val_y2_output_loss: 0.9215 - val_y1_output_root_mean_squared_error: 0.4778 - val_y2_output_root_mean_squared_error: 0.9726
# Epoch 469/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4135 - y1_output_loss: 0.1374 - y2_output_loss: 0.2725 - y1_output_root_mean_squared_error: 0.3720 - y2_output_root_mean_squared_error: 0.5245 - val_loss: 1.1258 - val_y1_output_loss: 0.2332 - val_y2_output_loss: 0.8713 - val_y1_output_root_mean_squared_error: 0.4792 - val_y2_output_root_mean_squared_error: 0.9466
# Epoch 470/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3394 - y1_output_loss: 0.1076 - y2_output_loss: 0.2292 - y1_output_root_mean_squared_error: 0.3291 - y2_output_root_mean_squared_error: 0.4807 - val_loss: 1.0593 - val_y1_output_loss: 0.2046 - val_y2_output_loss: 0.8281 - val_y1_output_root_mean_squared_error: 0.4558 - val_y2_output_root_mean_squared_error: 0.9228
# Epoch 471/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3076 - y1_output_loss: 0.1022 - y2_output_loss: 0.2052 - y1_output_root_mean_squared_error: 0.3186 - y2_output_root_mean_squared_error: 0.4540 - val_loss: 0.9945 - val_y1_output_loss: 0.1919 - val_y2_output_loss: 0.7801 - val_y1_output_root_mean_squared_error: 0.4384 - val_y2_output_root_mean_squared_error: 0.8957
# Epoch 472/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3199 - y1_output_loss: 0.1059 - y2_output_loss: 0.2129 - y1_output_root_mean_squared_error: 0.3261 - y2_output_root_mean_squared_error: 0.4621 - val_loss: 1.1399 - val_y1_output_loss: 0.1829 - val_y2_output_loss: 0.9199 - val_y1_output_root_mean_squared_error: 0.4316 - val_y2_output_root_mean_squared_error: 0.9765
# Epoch 473/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3375 - y1_output_loss: 0.0993 - y2_output_loss: 0.2364 - y1_output_root_mean_squared_error: 0.3157 - y2_output_root_mean_squared_error: 0.4876 - val_loss: 1.0420 - val_y1_output_loss: 0.1881 - val_y2_output_loss: 0.8230 - val_y1_output_root_mean_squared_error: 0.4398 - val_y2_output_root_mean_squared_error: 0.9212
# Epoch 474/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3195 - y1_output_loss: 0.1124 - y2_output_loss: 0.2099 - y1_output_root_mean_squared_error: 0.3365 - y2_output_root_mean_squared_error: 0.4541 - val_loss: 1.3253 - val_y1_output_loss: 0.2058 - val_y2_output_loss: 1.1003 - val_y1_output_root_mean_squared_error: 0.4603 - val_y2_output_root_mean_squared_error: 1.0552
# Epoch 475/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3122 - y1_output_loss: 0.1069 - y2_output_loss: 0.2028 - y1_output_root_mean_squared_error: 0.3284 - y2_output_root_mean_squared_error: 0.4520 - val_loss: 1.0847 - val_y1_output_loss: 0.2042 - val_y2_output_loss: 0.8519 - val_y1_output_root_mean_squared_error: 0.4560 - val_y2_output_root_mean_squared_error: 0.9363
# Epoch 476/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3140 - y1_output_loss: 0.1169 - y2_output_loss: 0.1971 - y1_output_root_mean_squared_error: 0.3428 - y2_output_root_mean_squared_error: 0.4433 - val_loss: 1.2584 - val_y1_output_loss: 0.2423 - val_y2_output_loss: 1.0167 - val_y1_output_root_mean_squared_error: 0.4832 - val_y2_output_root_mean_squared_error: 1.0124
# Epoch 477/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4094 - y1_output_loss: 0.1234 - y2_output_loss: 0.2832 - y1_output_root_mean_squared_error: 0.3526 - y2_output_root_mean_squared_error: 0.5339 - val_loss: 1.1098 - val_y1_output_loss: 0.2026 - val_y2_output_loss: 0.9006 - val_y1_output_root_mean_squared_error: 0.4456 - val_y2_output_root_mean_squared_error: 0.9546
# Epoch 478/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3131 - y1_output_loss: 0.1135 - y2_output_loss: 0.1985 - y1_output_root_mean_squared_error: 0.3377 - y2_output_root_mean_squared_error: 0.4461 - val_loss: 1.0925 - val_y1_output_loss: 0.2681 - val_y2_output_loss: 0.8184 - val_y1_output_root_mean_squared_error: 0.5080 - val_y2_output_root_mean_squared_error: 0.9135
# Epoch 479/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3023 - y1_output_loss: 0.0987 - y2_output_loss: 0.2031 - y1_output_root_mean_squared_error: 0.3152 - y2_output_root_mean_squared_error: 0.4504 - val_loss: 1.1034 - val_y1_output_loss: 0.2208 - val_y2_output_loss: 0.8484 - val_y1_output_root_mean_squared_error: 0.4761 - val_y2_output_root_mean_squared_error: 0.9363
# Epoch 480/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3194 - y1_output_loss: 0.1122 - y2_output_loss: 0.2089 - y1_output_root_mean_squared_error: 0.3355 - y2_output_root_mean_squared_error: 0.4547 - val_loss: 1.4741 - val_y1_output_loss: 0.4147 - val_y2_output_loss: 1.0690 - val_y1_output_root_mean_squared_error: 0.6370 - val_y2_output_root_mean_squared_error: 1.0336
# Epoch 481/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3278 - y1_output_loss: 0.1080 - y2_output_loss: 0.2171 - y1_output_root_mean_squared_error: 0.3299 - y2_output_root_mean_squared_error: 0.4680 - val_loss: 1.0223 - val_y1_output_loss: 0.1885 - val_y2_output_loss: 0.8154 - val_y1_output_root_mean_squared_error: 0.4336 - val_y2_output_root_mean_squared_error: 0.9134
# Epoch 482/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3784 - y1_output_loss: 0.1087 - y2_output_loss: 0.2674 - y1_output_root_mean_squared_error: 0.3300 - y2_output_root_mean_squared_error: 0.5192 - val_loss: 1.0083 - val_y1_output_loss: 0.1758 - val_y2_output_loss: 0.8084 - val_y1_output_root_mean_squared_error: 0.4263 - val_y2_output_root_mean_squared_error: 0.9092
# Epoch 483/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.4092 - y1_output_loss: 0.1330 - y2_output_loss: 0.2781 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.5295 - val_loss: 1.1639 - val_y1_output_loss: 0.2921 - val_y2_output_loss: 0.8537 - val_y1_output_root_mean_squared_error: 0.5489 - val_y2_output_root_mean_squared_error: 0.9288
# Epoch 484/500
# 614/614 [==============================] - 0s 151us/sample - loss: 0.3086 - y1_output_loss: 0.0991 - y2_output_loss: 0.2083 - y1_output_root_mean_squared_error: 0.3159 - y2_output_root_mean_squared_error: 0.4569 - val_loss: 1.1652 - val_y1_output_loss: 0.1751 - val_y2_output_loss: 0.9506 - val_y1_output_root_mean_squared_error: 0.4227 - val_y2_output_root_mean_squared_error: 0.9932
# Epoch 485/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.2904 - y1_output_loss: 0.1022 - y2_output_loss: 0.1882 - y1_output_root_mean_squared_error: 0.3178 - y2_output_root_mean_squared_error: 0.4352 - val_loss: 1.3251 - val_y1_output_loss: 0.2286 - val_y2_output_loss: 1.0583 - val_y1_output_root_mean_squared_error: 0.4850 - val_y2_output_root_mean_squared_error: 1.0440
# Epoch 486/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.4325 - y1_output_loss: 0.1356 - y2_output_loss: 0.2940 - y1_output_root_mean_squared_error: 0.3695 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 1.0109 - val_y1_output_loss: 0.1993 - val_y2_output_loss: 0.7849 - val_y1_output_root_mean_squared_error: 0.4523 - val_y2_output_root_mean_squared_error: 0.8980
# Epoch 487/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3138 - y1_output_loss: 0.1013 - y2_output_loss: 0.2241 - y1_output_root_mean_squared_error: 0.3157 - y2_output_root_mean_squared_error: 0.4628 - val_loss: 1.9386 - val_y1_output_loss: 0.3616 - val_y2_output_loss: 1.5814 - val_y1_output_root_mean_squared_error: 0.6020 - val_y2_output_root_mean_squared_error: 1.2555
# Epoch 488/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3126 - y1_output_loss: 0.1000 - y2_output_loss: 0.2115 - y1_output_root_mean_squared_error: 0.3167 - y2_output_root_mean_squared_error: 0.4608 - val_loss: 1.1256 - val_y1_output_loss: 0.2350 - val_y2_output_loss: 0.8665 - val_y1_output_root_mean_squared_error: 0.4817 - val_y2_output_root_mean_squared_error: 0.9453
# Epoch 489/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2727 - y1_output_loss: 0.0919 - y2_output_loss: 0.1800 - y1_output_root_mean_squared_error: 0.3037 - y2_output_root_mean_squared_error: 0.4247 - val_loss: 1.1241 - val_y1_output_loss: 0.1904 - val_y2_output_loss: 0.8989 - val_y1_output_root_mean_squared_error: 0.4394 - val_y2_output_root_mean_squared_error: 0.9649
# Epoch 490/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.2873 - y1_output_loss: 0.0947 - y2_output_loss: 0.1904 - y1_output_root_mean_squared_error: 0.3090 - y2_output_root_mean_squared_error: 0.4380 - val_loss: 1.0653 - val_y1_output_loss: 0.1913 - val_y2_output_loss: 0.8429 - val_y1_output_root_mean_squared_error: 0.4367 - val_y2_output_root_mean_squared_error: 0.9352
# Epoch 491/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.2792 - y1_output_loss: 0.0960 - y2_output_loss: 0.1832 - y1_output_root_mean_squared_error: 0.3091 - y2_output_root_mean_squared_error: 0.4286 - val_loss: 1.0733 - val_y1_output_loss: 0.2205 - val_y2_output_loss: 0.8264 - val_y1_output_root_mean_squared_error: 0.4751 - val_y2_output_root_mean_squared_error: 0.9207
# Epoch 492/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3838 - y1_output_loss: 0.1233 - y2_output_loss: 0.2609 - y1_output_root_mean_squared_error: 0.3513 - y2_output_root_mean_squared_error: 0.5103 - val_loss: 1.1054 - val_y1_output_loss: 0.1858 - val_y2_output_loss: 0.8853 - val_y1_output_root_mean_squared_error: 0.4358 - val_y2_output_root_mean_squared_error: 0.9568
# Epoch 493/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.2970 - y1_output_loss: 0.1029 - y2_output_loss: 0.1928 - y1_output_root_mean_squared_error: 0.3211 - y2_output_root_mean_squared_error: 0.4404 - val_loss: 1.0528 - val_y1_output_loss: 0.1838 - val_y2_output_loss: 0.8378 - val_y1_output_root_mean_squared_error: 0.4324 - val_y2_output_root_mean_squared_error: 0.9305
# Epoch 494/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2653 - y1_output_loss: 0.0996 - y2_output_loss: 0.1644 - y1_output_root_mean_squared_error: 0.3166 - y2_output_root_mean_squared_error: 0.4062 - val_loss: 1.0420 - val_y1_output_loss: 0.1810 - val_y2_output_loss: 0.8268 - val_y1_output_root_mean_squared_error: 0.4295 - val_y2_output_root_mean_squared_error: 0.9260
# Epoch 495/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2529 - y1_output_loss: 0.0918 - y2_output_loss: 0.1594 - y1_output_root_mean_squared_error: 0.3036 - y2_output_root_mean_squared_error: 0.4009 - val_loss: 1.0414 - val_y1_output_loss: 0.2139 - val_y2_output_loss: 0.8077 - val_y1_output_root_mean_squared_error: 0.4638 - val_y2_output_root_mean_squared_error: 0.9090
# Epoch 496/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4004 - y1_output_loss: 0.1663 - y2_output_loss: 0.2356 - y1_output_root_mean_squared_error: 0.4079 - y2_output_root_mean_squared_error: 0.4837 - val_loss: 1.2821 - val_y1_output_loss: 0.3824 - val_y2_output_loss: 0.8645 - val_y1_output_root_mean_squared_error: 0.6222 - val_y2_output_root_mean_squared_error: 0.9460
# Epoch 497/500
# 614/614 [==============================] - 0s 164us/sample - loss: 0.2925 - y1_output_loss: 0.1169 - y2_output_loss: 0.1761 - y1_output_root_mean_squared_error: 0.3399 - y2_output_root_mean_squared_error: 0.4207 - val_loss: 1.5950 - val_y1_output_loss: 0.4105 - val_y2_output_loss: 1.1483 - val_y1_output_root_mean_squared_error: 0.6441 - val_y2_output_root_mean_squared_error: 1.0863
# Epoch 498/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.8981 - y1_output_loss: 0.1908 - y2_output_loss: 0.6995 - y1_output_root_mean_squared_error: 0.4385 - y2_output_root_mean_squared_error: 0.8401 - val_loss: 0.9380 - val_y1_output_loss: 0.1865 - val_y2_output_loss: 0.7431 - val_y1_output_root_mean_squared_error: 0.4310 - val_y2_output_root_mean_squared_error: 0.8673
# Epoch 499/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2601 - y1_output_loss: 0.0986 - y2_output_loss: 0.1668 - y1_output_root_mean_squared_error: 0.3138 - y2_output_root_mean_squared_error: 0.4020 - val_loss: 1.9279 - val_y1_output_loss: 0.2722 - val_y2_output_loss: 1.6046 - val_y1_output_root_mean_squared_error: 0.5261 - val_y2_output_root_mean_squared_error: 1.2850
# Epoch 500/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3419 - y1_output_loss: 0.1189 - y2_output_loss: 0.2207 - y1_output_root_mean_squared_error: 0.3464 - y2_output_root_mean_squared_error: 0.4711 - val_loss: 0.9453 - val_y1_output_loss: 0.1713 - val_y2_output_loss: 0.7519 - val_y1_output_root_mean_squared_error: 0.4174 - val_y2_output_root_mean_squared_error: 0.8781

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 41us/sample - loss: 0.9453 - y1_output_loss: 0.1748 - y2_output_loss: 0.7654 - y1_output_root_mean_squared_error: 0.4174 - y2_output_root_mean_squared_error: 0.8781
# Loss = 0.9452690335063191, Y1_loss = 0.17483219504356384, Y1_mse = 0.4174003005027771, Y2_loss = 0.7653651833534241, Y2_mse = 0.8780922889709473

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
